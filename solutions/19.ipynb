# %% [markdown]
# # 19. Remove Nth Node From End of List
#
# Given the head of a linked list, remove the `n`th node
# from the end of the list and return its head.
#
# <div style="max-width: 500px; margin: auto">
#
# ![dialpad](./resources/19.jpeg)
#
# </div>
#
# ## Example 1:
#
# ```bash
# Input: head = [1,2,3,4,5], n = 2
# Output: [1,2,3,5]
# ```
#
# ## Example 2:
#
# ```bash
# Input: head = [1], n = 1
# Output: []
# ```
#
#
# ## Example 3:
#
# ```bash
# Input: head = [1,2], n = 1
# Output: [1]
# ```
#
# ## Constraints:
#
# - The number of nodes in the list is `sz`.
# - `1 <= sz <= 30`.
# - `0 <= Node.val <= 100`.
# - `1 <= n <= sz`.
#
# > Follow up: Could you do this in one pass?

# %%
from typing import Optional, List

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

    @staticmethod
    def from_list(vals: List):
        head = ListNode(None)
        tail = head

        for val in vals:
            tail.next = ListNode(val)
            tail = tail.next

        return head.next
    
    def to_list(self):
        vals = []
        node = self
        while node:
            vals.append(node.val)
            node = node.next
        return vals
    
    def __repr__(self):
        return str(self.to_list())
    
    def __eq__(self, other):
        return self.to_list() == other.to_list()
        

from typing import Optional
class Solution:
    def removeNthFromEnd(self, head: Optional[ListNode], n: int) -> Optional[ListNode]:

        if head is None:
            return

        slow = fast = head
        while fast and n > 0:
            
            if n == 1 and not fast.next:
                return head.next

            fast = fast.next
            n -= 1

        if not fast:
            return

        # slow = head

        while fast.next:
            fast = fast.next
            slow = slow.next

        assert slow is not None
        assert slow.next is not None

        slow.next = slow.next.next

        return head

# %%
solver = Solution()

test_cases = [
    ([1,2,3,4,5], 2, [1,2,3,5]),
    ([1], 1, []),
    ([1,2], 1, [1]),
]

for initial, n, expected in test_cases:
    head = ListNode.from_list(initial)
    actual = solver.removeNthFromEnd(head, n)
    actual = ListNode.to_list(actual)

    print(f"""
      {initial = }
      {n = }
      {actual = }
      {expected = }
    """)
    assert actual == expected
# Out:
#       initial = [1, 2, 3, 4, 5]
#       n = 2
#       actual = [1, 2, 3, 5]
#       expected = [1, 2, 3, 5]
#
#
#       initial = [1]
#       n = 1
#       actual = []
#       expected = []
#
#
#       initial = [1, 2]
#       n = 1
#       actual = [1]
#       expected = [1]
